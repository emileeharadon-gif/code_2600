# %% [markdown]
# # Module 04: Linear Regression

# %%
# packages
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from ISLP import load_data
from ISLP.models import (ModelSpec as MS, summarize)

# set seed
seed = 4721

# %% [markdown]
# ### We'll use the _Bikeshare_ data from ISLP for this activity. The metadata for _Bikeshare_ can be found [here](https://intro-stat-learning.github.io/ISLP/datasets/Bkeshare.html).

# %%
# Load the data
Bikeshare = load_data('Bikeshare')

# %%
# List the columns and their types
Bikeshare.dtypes
# Out:
# season           int64
# mnth          category
# day              int64
# hr            category
# holiday          int64
# weekday          int64
# workingday       int64
# weathersit    category
# temp           float64
# atemp          float64
# hum            float64
# windspeed      float64
# casual           int64
# registered       int64
# bikers           int64
# dtype: object

# %% [markdown]
# ### We will predict the `bikers` column, which is the total of casual and registered bikers.
# Then we can create a matrix of potential independent variables (X) and a dependent variable vector (y).

# %%
indep_vars = ['season', 'mnth', 'day', 'hr', 
              'holiday', 'weekday', 'workingday', 
              'weathersit', 'temp', 'atemp', 'hum', 'windspeed']

X = Bikeshare[indep_vars]
y = Bikeshare['bikers']

# %% [markdown]
# ### Before doing any other analyses, let's create training and test sets.

# %%
X_train, X_test, y_train, y_test, Train, Test = train_test_split(X, y, Bikeshare, 
                                                                 random_state = seed, 
                                                                 test_size = 0.25, 
                                                                 shuffle = True)

# %% [markdown]
# ### We can first summarize the variables in the training data.

# %%
Train.describe()
# Out:
#             season          day      holiday      weekday   workingday  \
# count  6483.000000  6483.000000  6483.000000  6483.000000  6483.000000
# mean      2.515502   184.328243     0.028382     3.035169     0.679932
# std       1.102100   104.578153     0.166074     2.013836     0.466538
# min       1.000000     1.000000     0.000000     0.000000     0.000000
# 25%       2.000000    95.000000     0.000000     1.000000     0.000000
# 50%       3.000000   185.000000     0.000000     3.000000     1.000000
# 75%       3.000000   274.000000     0.000000     5.000000     1.000000
# max       4.000000   365.000000     1.000000     6.000000     1.000000
#
#               temp        atemp          hum    windspeed       casual  \
# count  6483.000000  6483.000000  6483.000000  6483.000000  6483.000000
# mean      0.490066     0.469745     0.643862     0.191836    28.581212
# std       0.196942     0.175640     0.196966     0.124633    38.973040
# min       0.020000     0.000000     0.000000     0.000000     0.000000
# 25%       0.320000     0.318200     0.490000     0.104500     3.000000
# 50%       0.500000     0.484800     0.650000     0.194000    14.000000
# 75%       0.660000     0.621200     0.810000     0.283600    38.000000
# max       0.960000     1.000000     1.000000     0.850700   272.000000
#
#         registered       bikers
# count  6483.000000  6483.000000
# mean    114.752275   143.333488
# std     109.394295   133.938856
# min       0.000000     1.000000
# 25%      26.000000    31.000000
# 50%      89.000000   109.000000
# 75%     167.000000   211.000000
# max     567.000000   651.000000

# %% [markdown]
# ### Then we can create plots for each potential independent variable with `bikers` on training data.

# %%
# Initialize the plots before drawing them
nrows = 4
ncols = 3
figsize = (5*nrows, 5*ncols)

fig, axes = subplots(nrows=nrows,
                     ncols=ncols,
                     figsize=figsize)

# Assign a grid location to each index
def range_to_grid(i, nrows, ncols):
    x=[]
    y=[]
    for n in range(nrows*ncols):
        x.append(n // ncols)
        y.append(n % ncols)
        # print(n,x[n],y[n]) # for testing this function
    return x[i],y[i]

# Plot the variables
for j in range(len(X_train.columns)):
    # print(range_to_grid(j,nrows,ncols)[0], range_to_grid(j,nrows,ncols)[1]) # testing
    axes[range_to_grid(j,nrows,ncols)[0],
         range_to_grid(j,nrows,ncols)[1]].plot(X_train.iloc[:,j], y_train, 'o')
    axes[range_to_grid(j,nrows,ncols)[0],
         range_to_grid(j,nrows,ncols)[1]].set_xlabel(X_train.columns[j])

# %% [markdown]
# ### Explain why you can deduce that there likely are no missing values in this dataset.

# %% [markdown]
# "count" is the same for all variables in the table, meaning all values are filled in for all variables

# %% [markdown]
# ### The variables that have approximately linear relationship with `bikers` are `temp`, `atemp`, `windspeed`, `workingday`, and `holiday`.
#
# It appears that time-related variables (`season`, `day`, `hr`, etc.) have non-linear relationships with `bikers`, so we'll hold off on using these variables until the next module.

# %%
# correlation of potential linear variables
Train[['bikers', 'temp', 'atemp', 'windspeed', 'workingday', 'holiday']].corr()
# Out:
#               bikers      temp     atemp  windspeed  workingday   holiday
# bikers      1.000000  0.454993  0.451417   0.083514    0.018840 -0.022141
# temp        0.454993  1.000000  0.991996  -0.001199    0.068249 -0.022510
# atemp       0.451417  0.991996  1.000000  -0.041153    0.067167 -0.030258
# windspeed   0.083514 -0.001199 -0.041153   1.000000    0.002749  0.007133
# workingday  0.018840  0.068249  0.067167   0.002749    1.000000 -0.249106
# holiday    -0.022141 -0.022510 -0.030258   0.007133   -0.249106  1.000000

# %% [markdown]
# ### Explain why `temp` or `atemp` should be used to predict `bikers`, but NOT both.

# %% [markdown]
# temp and atemp are extremely closely correlated to each other (.991996) so only one of them should be used to predict bikers

# %% [markdown]
# ## First Linear Regression Model

# %% [markdown]
# ### We can create a column to represent the intercept in our model.
#
# Some packages do this automatically, but we will leverage the ISLP version, which does not.

# %%
X_train['intercept'] = np.ones(X_train.shape[0])
X_test['intercept'] = np.ones(X_test.shape[0])

# %% [markdown]
# ### Now we'll build a simple linear regression model that uses only `temp` and an intercept to predict `bikers`.

# %%
model_1 = sm.OLS(y_train, X_train[['intercept','temp']])
results_1 = model_1.fit()
summarize(results_1)
# Out:
#                coef  std err       t  P>|t|
# intercept   -8.3111    3.973  -2.092  0.036
# temp       309.4370    7.523  41.133  0.000

# %% [markdown]
# ### Use this model to predict the number of bikers on a 68F day.
#
# _Hint_: Use the [metadata](https://intro-stat-learning.github.io/ISLP/datasets/Bikeshare.html) and the fact that 68F = 20C.

# %% [markdown]
# 6180.429 bikers since y=-8.3111 + 309.4370(20)

# %% [markdown]
# ### We will evaluate this model *three ways*: Using R^2, using MSE, and then visually.
#
# For the last two, we will compare on _Train_ and on _Test_.

# %%
# R^2 on training
results_1.rsquared
# Out:
# np.float64(0.20701891421146124)

# %%
# Create helper functions for computing the mean squared error

def predict(X, model):
    # the built-in get_prediction tool returns an array, so we need to convert to a dataframe
    predictions_df = pd.DataFrame(model.get_prediction(X).predicted, columns=['y_hat'], index=X.index)
    return predictions_df['y_hat']

def mse(y, y_hat):
    # calculate the residual error for each individual record
    resid = y - y_hat
    # square the residual (hence "squared error")
    sq_resid = resid**2
    # calculate the sum of squared errors
    SSR = sum(sq_resid)
    # divide by the number of records to get the mean squared error
    MSE = SSR / y.shape[0]
    return MSE

# %%
predictions_train_1 = predict(X_train[['intercept', 'temp']], results_1)
print('MSE train: ', mse(y_train, predictions_train_1))

predictions_test_1 = predict(X_test[['intercept', 'temp']], results_1)
print('MSE test: ', mse(y_test, predictions_test_1))
# Out:
# MSE train:  14223.58284364993
# MSE test:  14355.465212031697

# %%
# Define a function to draw a line given coefficients [credit to Hastie & Tibshirani]

def abline(ax, b, m, *args, **kwargs):
    "Add a line with slope m and intercept b to ax"
    xlim = ax.get_xlim()
    ylim = [m * xlim[0] + b, m * xlim[1] + b]
    ax.plot(xlim, ylim, *args, **kwargs)

# %%
ax = Train.plot.scatter('temp', 'bikers')
ax.set_title("Plot of temp vs bikers (train)")
abline(ax,
       results_1.params[0],
       results_1.params[1],
       'r--',
       linewidth=3)
# Out:
# C:\Users\emile\AppData\Local\Temp\ipykernel_36284\2874524942.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results_1.params[0],
# C:\Users\emile\AppData\Local\Temp\ipykernel_36284\2874524942.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results_1.params[1],

# %%
ax = Test.plot.scatter('temp', 'bikers')
ax.set_title("Plot of temp vs bikers (test)")
abline(ax,
       results_1.params[0],
       results_1.params[1],
       'm--',
       linewidth=3)
# Out:
# C:\Users\emile\AppData\Local\Temp\ipykernel_36284\1080062984.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results_1.params[0],
# C:\Users\emile\AppData\Local\Temp\ipykernel_36284\1080062984.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results_1.params[1],

# %% [markdown]
# ### Using the same training set, build a new model that uses both temp and holiday to predict bikers.

# %%
model_2 = sm.OLS(y_train, X_train[['intercept', 'temp', 'holiday']])
results_2 = model_2.fit()
summarize(results_2)
# Out:
#                coef  std err       t  P>|t|
# intercept   -7.9493    3.987  -1.994  0.046
# temp       309.2547    7.525  41.099  0.000
# holiday     -9.6015    8.923  -1.076  0.282

# %% [markdown]
# ### Based on the summary of the new model, does it make sense to include `holiday` as a predictor? Why or why not?

# %% [markdown]
# no, the coefficient is very small in comparison to temp meaning it doesn't impact bikers that much.

# %% [markdown]
# ### Compute the R^2 coefficient for the new model.

# %%
results_2.rsquared
# Out:
# np.float64(0.2071605749999138)

# %% [markdown]
# ### Compute the MSE on the training and test sets for the new model.

# %%
predictions_train_2 = print(results_2.predict(X_train[['intercept', 'temp', 'holiday']]))

predictions_test_2 = print(results_2.predict(X_test[['intercept', 'temp', 'holiday']]))
# Out:
# 708      60.086713
# 403      60.086713
# 3239    159.048220
# 2231    128.122749
# 2295    121.937655
#            ...
# 8462     84.827090
# 2728    183.788597
# 4778    245.639539
# 890      53.901619
# 2890    121.937655
# Length: 6483, dtype: float64
# 685      41.531431
# 1307    140.492938
# 5302    202.343879
# 802      72.456902
# 3133    177.603503
#            ...
# 7736     97.197278
# 4791    282.750104
# 3317    159.048220
# 187      22.976148
# 4406    251.824633
# Length: 2162, dtype: float64

# %% [markdown]
# ### Based on the MSE calculations, is this model better or worse than the model containing only `temp`? Why or why not?

# %% [markdown]
# This model performs worse than the model that only used temp since adding holiday didn't reduce the test MSE. This means that holiday doesn't have predictive value and only increases overfitting since it did slightly decrease the MSE on the training data.

# %% [markdown]
# ### Now build a model using `windspeed` instead of `holiday` as a predictor.

# %%
model_3 = #fillin
results_3 = #fillin
summarize(results_3)

# %% [markdown]
# ### Compute the R^2 for this model.

# %%
#fillin

# %% [markdown]
# ### Compute the MSE for this model on train and test.

# %%
predictions_train_3 = #fillin

predictions_test_3 = #fillin

# %% [markdown]
# ### Out of the three models, which would you choose? Why?

# %% [markdown]
# #fillin Type your answer here.
